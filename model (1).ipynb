# %% [markdown]
# <a href="https://colab.research.google.com/github/zenyc/text-summarizer/blob/master/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import pandas as pd 
import re           
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
# warnings.filterwarnings("ignore")

# %%
proj_dir = "/content/drive/My Drive/Projects/text-summarizer/proj-dir/"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
proj_dir[:-9]
# Out:
# '/content/drive/My Drive/Projects/text-summarizer/'

# %%
import shutil
shutil.copy(proj_dir[:-9]+"attention.py",".")
# Out:
# './attention.py'

# %%
import attention

# %%
AttentionLayer = attention.AttentionLayer

# %%
data=pd.read_csv(proj_dir+"Reviews.csv",
                 nrows=10000
                )

# %%
data.head()
# Out:
#    Id  ...                                                                                                                                                                                                     Text
# 0   1  ...  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1   2  ...           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2   3  ...  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3   4  ...  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4   5  ...                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
#
# [5 rows x 10 columns]

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  #dropping duplicates
data.dropna(axis=0,inplace=True)   #dropping na

# %%
data
# Out:
#          Id  ...                                                                                                                                                                                                     Text
# 0         1  ...  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1         2  ...           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2         3  ...  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3         4  ...  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4         5  ...                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# ...     ...  ...                                                                                                                                                                                                      ...
# 9995   9996  ...  we switched from the advance similac to the organic product thinking it would be better as we prefer organic foods ourselves. it was a disaster with our 2 month old baby getting constipated and pr...
# 9996   9997  ...  Like the bad reviews say, the organic formula constipated our daughter. However, by alternating every other feeding with regular (non-organic) formula the problem was resolved. I'm a believer that...
# 9997   9998  ...  I wanted to solely breastfeed but was unable to keep up and had to supplement formula.  I chose Similac because they are a very reputable company and I had a ton of it from the hospital.  We have ...
# 9998   9999  ...                                                                                   i love the fact that i can get this delieved to my house with no delievy charge.it is so hard to find organic formular
# 9999  10000  ...  We have a 7 week old... He had gas and constipation problems for the first 5 weeks. We tried two different kinds of similac including for fussiness and gas and neither seemed to work. We switched ...
#
# [9513 rows x 10 columns]

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: _START_ good quality dog food  _END_
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: _START_ not as advertised  _END_
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: _START_ delight says it all  _END_
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: _START_ cough medicine  _END_
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: _START_ great taffy  _END_

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=80 
max_len_summary=10

# %%
data["cleaned_summary"] = data["cleaned_summary"].reset_index(drop=True)

# %%
data["cleaned_text"] = data["cleaned_text"].reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
list(y_tr)
# Out:
# ['_START_ chocolate treat  _END_',
#  '_START_ healthy dog food  _END_',
#  '_START_ absolutely the best  _END_',
#  '_START_ tatsy  _END_',
#  '_START_ great coffee  _END_',
#  '_START_ too much sugar too expensive  _END_',
#  '_START_ love these chips  _END_',
#  '_START_ yummy  _END_',
#  '_START_ love it  _END_',
#  '_START_ great coffee  _END_',
#  '_START_ tasted ok bit overpriced tho  _END_',
#  '_START_ wonderful cups  _END_',
#  '_START_ big tub salt  _END_',
#  '_START_ hot chocolate in seconds  _END_',
#  '_START_ ugh so not what was expecting lt  _END_',
#  '_START_ great sauce  _END_',
#  '_START_ candy tree organic cherry bites  _END_',
#  '_START_ hydrating refreshing great tasting drink  _END_',
#  '_START_ safe easy to chew tasty for dogs  _END_',
#  '_START_ the best salad seasoning ever made  _END_',
#  '_START_ great taste the whole family loves  _END_',
#  '_START_ perfect  _END_',
#  '_START_ good licorice  _END_',
#  '_START_ not sure  _END_',
#  '_START_ china  _END_',
#  '_START_ delicious  _END_',
#  '_START_ trusted name  _END_',
#  '_START_ decent spice rub for red meats  _END_',
#  '_START_ quite delicious but not as good as real chips  _END_',
#  '_START_ excellent as bbq kebob marinade  _END_',
#  '_START_ tastes like hot sugar water  _END_',
#  '_START_ flavor did not work for me back to honey nut  _END_',
#  '_START_ tasty  _END_',
#  '_START_ slight quality control issue  _END_',
#  '_START_ had my doubts but am impressed  _END_',
#  '_START_ awsome  _END_',
#  '_START_ the best coffee for depression and lifting up your mood  _END_',
#  '_START_ rotton upon receipt  _END_',
#  '_START_ walnut oil  _END_',
#  '_START_ just  _END_',
#  '_START_ grainy and little oily but thick  _END_',
#  '_START_ ok  _END_',
#  '_START_ great dane loves it  _END_',
#  '_START_ real customer service  _END_',
#  '_START_ awefull  _END_',
#  '_START_ cloudy means impurities  _END_',
#  '_START_ so good eat it straight from the jar  _END_',
#  '_START_ used to be my favorite chips  _END_',
#  '_START_ good quality  _END_',
#  '_START_ great product and great cause  _END_',
#  '_START_ love the others not the bars  _END_',
#  '_START_ it works but not as expected  _END_',
#  '_START_ one of the best coffees  _END_',
#  '_START_ very weak flavor definately not watermelon  _END_',
#  '_START_ awesome buy for sure  _END_',
#  '_START_ roy from columbia ct  _END_',
#  '_START_ love popchips  _END_',
#  '_START_ taste as advertised  _END_',
#  '_START_ great buy  _END_',
#  '_START_ promising if it works not always guaranteed solution  _END_',
#  '_START_ great taste but honestly what goes inside read on  _END_',
#  '_START_ water for my pets  _END_',
#  '_START_ very good  _END_',
#  '_START_ great organic tea at great price  _END_',
#  '_START_ so awful can barely describe  _END_',
#  '_START_ great grass  _END_',
#  '_START_ wolfgand puck rodeo drive cup  _END_',
#  '_START_ easter basket  _END_',
#  '_START_ ghirardelli chocolate premium hot cocoa mix chocolate mocha ounce tins pack of  _END_',
#  '_START_ quality for good price  _END_',
#  '_START_ great product no hormones or antibiotics in the meat  _END_',
#  '_START_ likes it  _END_',
#  '_START_ amazon nut  _END_',
#  '_START_ great stuff  _END_',
#  '_START_ pop chips yum  _END_',
#  '_START_ sparkles  _END_',
#  '_START_ good healthy dessert but needs work  _END_',
#  '_START_ not like the wheatgrass in stores  _END_',
#  '_START_ colcafe greaatt coffee  _END_',
#  '_START_ our twins love this one with the subscription the price is fair  _END_',
#  '_START_ great product and timely delivery  _END_',
#  '_START_ love these  _END_',
#  '_START_ great but eat fast  _END_',
#  '_START_ new amazon com sells biscuit crumbs  _END_',
#  '_START_ senseo paris french vanilla coffee pods  _END_',
#  '_START_ love disposakups  _END_',
#  '_START_ disposable is great  _END_',
#  '_START_ fiesta sweet corn cake  _END_',
#  '_START_ swiss chalet  _END_',
#  '_START_ great snack for toddlers  _END_',
#  '_START_ smelled horrible and gave the dogs the runs  _END_',
#  '_START_ really good  _END_',
#  '_START_ like an indian meal in stick  _END_',
#  '_START_ fizzy citrus  _END_',
#  '_START_ great flavor  _END_',
#  '_START_ chocolate wafers in an identity crisis as oreos but if deception helps monitor calories why not  _END_',
#  '_START_ nice flavor but very weak  _END_',
#  '_START_ love this creamy coffee  _END_',
#  '_START_ very reasonably priced and delicious  _END_',
#  '_START_ good for cooking  _END_',
#  '_START_ was surprised with the layer of fat on top of contents  _END_',
#  '_START_ koma works and tastes great  _END_',
#  '_START_ disappointing filled bones  _END_',
#  '_START_ love these  _END_',
#  '_START_ great alternative  _END_',
#  '_START_ delicious  _END_',
#  '_START_ wish were in hawaii  _END_',
#  '_START_ highly addictive  _END_',
#  '_START_ loved these tartlets  _END_',
#  '_START_ lifesaver  _END_',
#  '_START_ the best  _END_',
#  '_START_ hot cocoa cups  _END_',
#  '_START_ inside of can corroded  _END_',
#  '_START_ what happened  _END_',
#  '_START_ good coffee with great service  _END_',
#  '_START_ love it use it for so many things including my mother secret recipe  _END_',
#  '_START_ simple but good  _END_',
#  '_START_ liquor filled chocolate gift box  _END_',
#  '_START_ low calorie tooth friendly and my dog loves them  _END_',
#  '_START_ our favorite grocery store chocolate chip cookie  _END_',
#  '_START_ some cans tastes good others horrid  _END_',
#  '_START_ bent in delivery  _END_',
#  '_START_ best packaged gravy ever made in my humble opinion  _END_',
#  '_START_ this food is not unbalanced  _END_',
#  '_START_ miam miam  _END_',
#  '_START_ good coffee with some exceptions  _END_',
#  '_START_ low in calories high in taste  _END_',
#  '_START_ we love newmans adult dog food  _END_',
#  '_START_ berres brothers coffee breakfast blend pkg ground  _END_',
#  '_START_ gross  _END_',
#  '_START_ good soy sauce but not special mainly good as unique gift  _END_',
#  '_START_ adorable basket makes nice presentation  _END_',
#  '_START_ coffee is good name is good  _END_',
#  '_START_ what truffle  _END_',
#  '_START_ vendor ripped off all of their cultures from other vendors  _END_',
#  '_START_ wheat free alternative  _END_',
#  '_START_ would be great product if it was easier to open  _END_',
#  '_START_ excellent product  _END_',
#  '_START_ good value for great treats  _END_',
#  '_START_ orgasmic  _END_',
#  '_START_ moisturizing skin softener great smell  _END_',
#  '_START_ great intro to spherification  _END_',
#  '_START_ delicious and easy  _END_',
#  '_START_ tasty pancakes but little flat  _END_',
#  '_START_ the new juice  _END_',
#  '_START_ great for running recovery  _END_',
#  '_START_ elegant english honey almond all butter biscuits  _END_',
#  '_START_ purina busy bone lethal product for your dog  _END_',
#  '_START_ lovely seeds for your cereal baking or yogurt  _END_',
#  '_START_ just soda  _END_',
#  '_START_ good plain natural sunflower butter  _END_',
#  '_START_ no effect on anyone in our family  _END_',
#  '_START_ new holiday tradition  _END_',
#  '_START_ too good to be healthy  _END_',
#  '_START_ not good  _END_',
#  '_START_ disappointing  _END_',
#  '_START_ peppermint is our favorite  _END_',
#  '_START_ palatable and healthy  _END_',
#  '_START_ wish my dog liked it  _END_',
#  '_START_ barely any vanilla aroma or flavor  _END_',
#  '_START_ best canned clam chowder have ever had  _END_',
#  '_START_ awesome  _END_',
#  '_START_ gourmet powerful salt vinegar chips  _END_',
#  '_START_ good price great for stocking up  _END_',
#  '_START_ great product  _END_',
#  '_START_ love the dark rich flavor  _END_',
#  '_START_ bad taste  _END_',
#  '_START_ great tasting crackers  _END_',
#  '_START_ best baby food out there if you are not making your own  _END_',
#  '_START_ amazon makes mama happy again  _END_',
#  '_START_ easy assembly great for alpacas  _END_',
#  '_START_ ok but not something they eat with enthusiasm  _END_',
#  '_START_ worked for hours then stopped  _END_',
#  '_START_ love this  _END_',
#  '_START_ much smaller than the picture leads one to believe  _END_',
#  '_START_ good but not wolfgang puck good  _END_',
#  '_START_ really good mix  _END_',
#  '_START_ not bad for instant healthy coffee  _END_',
#  '_START_ awesome tea  _END_',
#  '_START_ make fresh fruit tart light and beautiful  _END_',
#  '_START_ has partially hydrogenated coconut oil  _END_',
#  '_START_ very good  _END_',
#  '_START_ greatest healthy snack  _END_',
#  '_START_ melts in your mouth  _END_',
#  '_START_ the best  _END_',
#  '_START_ dog loves this food  _END_',
#  '_START_ great product for the price  _END_',
#  '_START_ great flavor  _END_',
#  '_START_ deeeeelicious  _END_',
#  '_START_ gets an plus for juice and no hfcs  _END_',
#  '_START_ decaf  _END_',
#  '_START_ perfect hot choc variety box  _END_',
#  '_START_ my cat is addicted lol  _END_',
#  '_START_ quality tea  _END_',
#  '_START_ stash instant green tea  _END_',
#  '_START_ love it  _END_',
#  '_START_ extremely disappointing  _END_',
#  '_START_ dissapointed in order  _END_',
#  '_START_ bad  _END_',
#  '_START_ the best instant coffee have found  _END_',
#  '_START_ sickness and death  _END_',
#  '_START_ tortillas scarce as honest politicians  _END_',
#  '_START_ jv  _END_',
#  '_START_ great bread  _END_',
#  '_START_ deliciously scrumptious  _END_',
#  '_START_ my new obsession  _END_',
#  '_START_ good beef sticks  _END_',
#  '_START_ harmony farms review  _END_',
#  '_START_ happy tummy  _END_',
#  '_START_ both cats threw up for long time  _END_',
#  '_START_ great tasting water  _END_',
#  '_START_ gluten free bliss  _END_',
#  '_START_ love them  _END_',
#  '_START_ nice and fresh  _END_',
#  '_START_ it bird seed  _END_',
#  '_START_ not completely bpa free  _END_',
#  '_START_ never tried the product just review for the shipping  _END_',
#  '_START_ so so  _END_',
#  '_START_ yummo  _END_',
#  '_START_ break from allergy baking from scratch  _END_',
#  '_START_ best muffins in the world  _END_',
#  '_START_ baby loves the tender beef spinach  _END_',
#  '_START_ mini cookies with mini merits  _END_',
#  '_START_ tastes just like remember  _END_',
#  '_START_ great for dogs  _END_',
#  '_START_ customer sevice  _END_',
#  '_START_ protein powder to make you gag  _END_',
#  '_START_ just ok  _END_',
#  '_START_ rave review for rolled oats  _END_',
#  '_START_ best ever  _END_',
#  '_START_ real licorice  _END_',
#  '_START_ cheaper than other brands  _END_',
#  '_START_ makes great pancakes  _END_',
#  '_START_ stephen gourmet hot cocoa cherry chocolate ounce cans pack of  _END_',
#  '_START_ horizon aspetic plain organic milk cartons  _END_',
#  '_START_ very watermelon flavored  _END_',
#  '_START_ decilious  _END_',
#  '_START_ amazing company  _END_',
#  '_START_ mrs mays anonymous  _END_',
#  '_START_ delicious and easy  _END_',
#  '_START_ best spicy nuts you can pop in your mouth  _END_',
#  '_START_ spray garlic  _END_',
#  '_START_ love it  _END_',
#  '_START_ great all around mix  _END_',
#  '_START_ grove square  _END_',
#  '_START_ fantastic orange tea  _END_',
#  '_START_ different product than the photo  _END_',
#  '_START_ easy to grow and cats love it  _END_',
#  '_START_ my favorite crackers  _END_',
#  '_START_ pure brilliant strategy from lakewood short bus marketing team  _END_',
#  '_START_ ehhh  _END_',
#  '_START_ wish would have bought more  _END_',
#  '_START_ my dog favorite  _END_',
#  '_START_ best tasting  _END_',
#  '_START_ perfect treat  _END_',
#  '_START_ great shape for dipping  _END_',
#  '_START_ grainy texture  _END_',
#  '_START_ sublime fragrance and taste  _END_',
#  '_START_ great product  _END_',
#  '_START_ quick to ship and tasty  _END_',
#  '_START_ best dog food for the price  _END_',
#  '_START_ switch flashback to my childhood bad memories man  _END_',
#  '_START_ cup cocoa  _END_',
#  '_START_ mberry miracle fruit tablets  _END_',
#  '_START_ delicious  _END_',
#  '_START_ this is the best dog food out there  _END_',
#  '_START_ pasty noodle mash at the end of serving  _END_',
#  '_START_ um package change from oz to oz  _END_',
#  '_START_ item as described shipped on time thanks  _END_',
#  '_START_ great product unbeatable price  _END_',
#  '_START_ beefaroni mostly macaroni  _END_',
#  '_START_ simplicity at it is best  _END_',
#  '_START_ great spice blend  _END_',
#  '_START_ fortune cookies  _END_',
#  '_START_ pocky  _END_',
#  '_START_ about the only good thing  _END_',
#  '_START_ better than thought they would be  _END_',
#  '_START_ delisious pancakes  _END_',
#  '_START_ just my cents  _END_',
#  '_START_ om nom nom  _END_',
#  '_START_ highly recommended hot chocolate  _END_',
#  '_START_ tasty  _END_',
#  '_START_ how dogfood should be  _END_',
#  '_START_ so far so good  _END_',
#  '_START_ excellent product  _END_',
#  '_START_ mackerel  _END_',
#  '_START_ exactly what ordered  _END_',
#  '_START_ too much for shipping  _END_',
#  '_START_ best brown sugar cubes  _END_',
#  '_START_ cocoa  _END_',
#  '_START_ yummy jerky strips  _END_',
#  '_START_ eat them up yum  _END_',
#  '_START_ great coffee  _END_',
#  '_START_ just ok  _END_',
#  '_START_ made in the usa  _END_',
#  '_START_ great deal  _END_',
#  '_START_ tastes great  _END_',
#  '_START_ love snacks  _END_',
#  '_START_ too much mint  _END_',
#  '_START_ best deal ever  _END_',
#  '_START_ jolokia salsa review  _END_',
#  '_START_ not what ordered  _END_',
#  '_START_ healthier alternative to soda but not overly original  _END_',
#  '_START_ excellent popcorn  _END_',
#  '_START_ great sticks  _END_',
#  '_START_ premium dog food  _END_',
#  '_START_ taters  _END_',
#  '_START_ great compared to other instant coffees  _END_',
#  '_START_ nt  _END_',
#  '_START_ uneatable  _END_',
#  '_START_ good stuff  _END_',
#  '_START_ nasty  _END_',
#  '_START_ horrid  _END_',
#  '_START_ fondarific fondant  _END_',
#  '_START_ yummo  _END_',
#  '_START_ oatmeal another choice  _END_',
#  '_START_ the only treats will use  _END_',
#  '_START_ great food for all cats  _END_',
#  '_START_ beef jerkey is amazing  _END_',
#  '_START_ great gift for the foodie in your life  _END_',
#  '_START_ great product beautiful sound  _END_',
#  '_START_ not my cup of cocoa  _END_',
#  '_START_ lovely lovely taste but be sure to shake before using  _END_',
#  '_START_ yum yum love me pop chips  _END_',
#  '_START_ fazer chocolate delightful treat  _END_',
#  '_START_ mentos  _END_',
#  '_START_ delicious  _END_',
#  '_START_ excellent service and product  _END_',
#  '_START_ love of taffy  _END_',
#  '_START_ best cherry chocolate that have come across  _END_',
#  '_START_ fantastic gravy mix  _END_',
#  '_START_ good food  _END_',
#  '_START_ taste lacks  _END_',
#  '_START_ delicious  _END_',
#  '_START_ false advertising  _END_',
#  '_START_ this is great french roast  _END_',
#  '_START_ tastes great  _END_',
#  '_START_ what treat  _END_',
#  '_START_ the best  _END_',
#  '_START_ happily home  _END_',
#  '_START_ the best food for dogs  _END_',
#  '_START_ our baby loves this milk  _END_',
#  '_START_ very nice smooth americano style coffee  _END_',
#  '_START_ full bodied but bitter  _END_',
#  '_START_ this tea works feel so much better  _END_',
#  '_START_ great seasoning  _END_',
#  '_START_ great snack  _END_',
#  '_START_ addictive and tasty  _END_',
#  '_START_ too sweet  _END_',
#  '_START_ sweet and carbonated like energy drinks but without the sugar  _END_',
#  '_START_ favorite cheese made in the usa  _END_',
#  '_START_ pure pleasure  _END_',
#  '_START_ makes great skinny margarita  _END_',
#  '_START_ healthy breakfast  _END_',
#  '_START_ no coffee flavor high calorie count  _END_',
#  '_START_ best flavor  _END_',
#  '_START_ great gum will buy more  _END_',
#  '_START_ good light to medium brew  _END_',
#  '_START_ great coffee but amazon price is too high  _END_',
#  '_START_ great taste not too sweet very refreshing  _END_',
#  '_START_ great quality food and my cats love it  _END_',
#  '_START_ excellent everyday olive oil  _END_',
#  '_START_ don like it  _END_',
#  '_START_ really cute made great golf cake  _END_',
#  '_START_ green tea  _END_',
#  '_START_ great price on great tea  _END_',
#  '_START_ love this tea  _END_',
#  '_START_ kona subscriber weighs in  _END_',
#  '_START_ my dog loves this food  _END_',
#  '_START_ healthy snack  _END_',
#  '_START_ at whole foods  _END_',
#  '_START_ delicious truffle goodness  _END_',
#  '_START_ popchips vs baked lays baked lays taste much better  _END_',
#  '_START_ this is great tea  _END_',
#  '_START_ this is their best bar by far  _END_',
#  '_START_ devine white clam sauce  _END_',
#  '_START_ delish  _END_',
#  '_START_ this stuff is the greatest  _END_',
#  '_START_ excellent jerky  _END_',
#  '_START_ kind of like faygo or slice  _END_',
#  '_START_ popchips  _END_',
#  '_START_ great stuff  _END_',
#  '_START_ healthy treat  _END_',
#  '_START_ excellent product pricey not enough product in the box for family of  _END_',
#  '_START_ delicious and hard to find  _END_',
#  '_START_ yowzah  _END_',
#  '_START_ sweet and refreshing  _END_',
#  '_START_ allday energy  _END_',
#  '_START_ love these things  _END_',
#  '_START_ very harsh too sweet flavor  _END_',
#  '_START_ cups  _END_',
#  '_START_ almond pops with blueberries  _END_',
#  '_START_ worst frosting ever  _END_',
#  '_START_ superior in every way  _END_',
#  '_START_ jack treats  _END_',
#  '_START_ the best cheetos out there  _END_',
#  '_START_ my child loves them  _END_',
#  '_START_ disposakups disposalbe cups for keurig brewers  _END_',
#  '_START_ unlisted ingredient of baxter lobster bisque  _END_',
#  '_START_ good fruity gum  _END_',
#  '_START_ love it so tasty  _END_',
#  '_START_ icicle on mac os  _END_',
#  '_START_ kettle chips  _END_',
#  '_START_ old and stale  _END_',
#  '_START_ ricore forever  _END_',
#  '_START_ hard to tell  _END_',
#  '_START_ not what expected  _END_',
#  '_START_ love this dog food  _END_',
#  '_START_ annie homegrown organic whole wheat shells white cheddar macaroni cheese oz  _END_',
#  '_START_ makes great cup of coffee  _END_',
#  '_START_ too salty  _END_',
#  '_START_ great for summer hydration  _END_',
#  '_START_ treat of the day  _END_',
#  '_START_ my cat loves em  _END_',
#  '_START_ yuk  _END_',
#  '_START_ an acquired taste  _END_',
#  '_START_ not in grocery stores  _END_',
#  '_START_ no complaints  _END_',
#  '_START_ easy vegan menu item  _END_',
#  '_START_ weeks pregnant these are my go to item  _END_',
#  '_START_ superior product gmo free  _END_',
#  '_START_ great coffee  _END_',
#  '_START_ hated it  _END_',
#  '_START_ ahhhh  _END_',
#  '_START_ great cup jo  _END_',
#  '_START_ great taste and great price  _END_',
#  '_START_ delicious  _END_',
#  '_START_ crispy light  _END_',
#  '_START_ don be fooled by the word espresso  _END_',
#  '_START_ these chips make me weak at the knees  _END_',
#  '_START_ just an fyi  _END_',
#  '_START_ good but pricey  _END_',
#  '_START_ pupstar  _END_',
#  '_START_ enjoyed by the whole family  _END_',
#  '_START_ poor choice  _END_',
#  '_START_ perfect pancakes enough said  _END_',
#  '_START_ ghirardelli chocolate mocha hot cocoa oz can  _END_',
#  '_START_ absolutely wonderful  _END_',
#  '_START_ the best  _END_',
#  '_START_ works for me  _END_',
#  '_START_ did you really make this  _END_',
#  '_START_ corgi approved  _END_',
#  '_START_ quality dog food delivered to your door  _END_',
#  '_START_ perfect blend of spice and vinegar  _END_',
#  '_START_ not bad not great  _END_',
#  '_START_ love mueslix  _END_',
#  '_START_ just so so  _END_',
#  '_START_ disposakups  _END_',
#  '_START_ great product  _END_',
#  '_START_ love it  _END_',
#  '_START_ nice fruity flavor  _END_',
#  '_START_ recent talk with customer relations re bpa liner  _END_',
#  '_START_ best popcorn ever  _END_',
#  '_START_ quality  _END_',
#  '_START_ winner in the iron category  _END_',
#  '_START_ fresh  _END_',
#  '_START_ arrived fast  _END_',
#  '_START_ about chicken meal  _END_',
#  '_START_ good stuff  _END_',
#  '_START_ tasty hot sauce  _END_',
#  '_START_ not as pictured  _END_',
#  '_START_ acceptable inexpensive but great when cold brewed  _END_',
#  '_START_ ice tea  _END_',
#  '_START_ it died three days after receiving it  _END_',
#  '_START_ great taste  _END_',
#  '_START_ almost five  _END_',
#  '_START_ best dog food ever  _END_',
#  '_START_ nicely thought out kit for temporary grazing etc  _END_',
#  '_START_ somewhat disappointed  _END_',
#  '_START_ really nice taste  _END_',
#  '_START_ disposa cups filters  _END_',
#  '_START_ great seeds  _END_',
#  '_START_ closest in the market to the real thing  _END_',
#  '_START_ great candy  _END_',
#  '_START_ healtier but not guilt free  _END_',
#  '_START_ an extremely pleasant carbonated drink  _END_',
#  '_START_ sugar free salty goodness  _END_',
#  '_START_ could be better  _END_',
#  '_START_ nice tree but where is the rest  _END_',
#  '_START_ love these colors  _END_',
#  '_START_ excellent  _END_',
#  '_START_ patty shells  _END_',
#  '_START_ will not purchase again  _END_',
#  '_START_ oz bag of skittles  _END_',
#  '_START_ love these twists  _END_',
#  '_START_ the pleasure of dining in  _END_',
#  '_START_ sees candies  _END_',
#  '_START_ caramel  _END_',
#  '_START_ not worth the cost  _END_',
#  '_START_ nice tofu  _END_',
#  '_START_ not extra bold  _END_',
#  '_START_ popchips hmmmm hmmm hmmm  _END_',
#  '_START_ fine citrus beverage from the switch  _END_',
#  '_START_ it is fabulous but not from amazon  _END_',
#  '_START_ tasty and healthy  _END_',
#  '_START_ twinings good cup of tea  _END_',
#  '_START_ great product  _END_',
#  '_START_ great product weak packaging  _END_',
#  '_START_ great gift and is delicious  _END_',
#  '_START_ yummy  _END_',
#  '_START_ not bad but little hard to get used to  _END_',
#  '_START_ great product and would buy again  _END_',
#  '_START_ starbucks instant coffee what surprise great  _END_',
#  '_START_ great tea  _END_',
#  '_START_ neither cat will touch it but dogs go wild star for dog food treat  _END_',
#  '_START_ too much caramel cream not enough coffee  _END_',
#  '_START_ waste of money  _END_',
#  '_START_ excellent variety our month old loves them all but be informed water is the largest ingrident by weight on all  _END_',
#  '_START_ disposable kcups and filters  _END_',
#  '_START_ pop chips better tasting and better for you than regular chips  _END_',
#  '_START_ cereal is great price is awful  _END_',
#  '_START_ great hot chocolate  _END_',
#  '_START_ small can  _END_',
#  '_START_ willy wonkalicious  _END_',
#  '_START_ dr pepper  _END_',
#  '_START_ sugar in the raw  _END_',
#  '_START_ disposakups  _END_',
#  '_START_ why cannot anyone make hot cocoa without sucralose splenda in it  _END_',
#  '_START_ broke after several uses  _END_',
#  '_START_ price keeps increasing  _END_',
#  '_START_ yummy healthy snack we love  _END_',
#  '_START_ instant coffee  _END_',
#  '_START_ great product  _END_',
#  '_START_ not what expected  _END_',
#  '_START_ innocence lost  _END_',
#  '_START_ not bad like the tropical riesling better  _END_',
#  '_START_ best for sweets  _END_',
#  '_START_ tasty chips  _END_',
#  '_START_ good dirty martini  _END_',
#  '_START_ coconut in the morning  _END_',
#  '_START_ life altering milk  _END_',
#  '_START_ switch to real energy drink  _END_',
#  '_START_ excellent chip  _END_',
#  '_START_ egg protein  _END_',
#  '_START_ enjoyable cup of coffee  _END_',
#  '_START_ ketchup powdery coating excessive overdone gritty  _END_',
#  '_START_ great quality  _END_',
#  '_START_ tea  _END_',
#  '_START_ skittles are tasty  _END_',
#  '_START_ both my cats eat this one  _END_',
#  '_START_ melted  _END_',
#  '_START_ bad product  _END_',
#  '_START_ simply the dest  _END_',
#  '_START_ soft and smelly  _END_',
#  '_START_ breakfast in bed review  _END_',
#  '_START_ should have listened to other bad reviews  _END_',
#  '_START_ best tasting soft wheat flour  _END_',
#  '_START_ watch out they are addictive  _END_',
#  '_START_ always fresh  _END_',
#  '_START_ best seeds ever lapped lip around  _END_',
#  '_START_ liquor filled chocolates  _END_',
#  '_START_ not impressed  _END_',
#  '_START_ light vanilla flavor  _END_',
#  '_START_ disappointed  _END_',
#  '_START_ we really did not like these  _END_',
#  '_START_ yuck  _END_',
#  '_START_ great buy  _END_',
#  '_START_ great  _END_',
#  '_START_ great healthy cat treats  _END_',
#  '_START_ great flavor wish it had longer shelf life  _END_',
#  '_START_ the best  _END_',
#  '_START_ somewhat disappointing  _END_',
#  '_START_ chocoholic view  _END_',
#  '_START_ the food is great but the bag sucks  _END_',
#  '_START_ just plain gross  _END_',
#  '_START_ rich chocolatey beverage mix  _END_',
#  '_START_ great cup of coffee  _END_',
#  '_START_ pocky sticks together  _END_',
#  '_START_ excellent soda alternative  _END_',
#  '_START_ right size taste  _END_',
#  '_START_ same stuff  _END_',
#  '_START_ just blah  _END_',
#  '_START_ great little rice patties  _END_',
#  '_START_ happy cats  _END_',
#  '_START_ awesome snack great product  _END_',
#  '_START_ my dog really likes iams savory sauce  _END_',
#  '_START_ soft just the right amout of flavor  _END_',
#  '_START_ bisphenol  _END_',
#  '_START_ no worries good stuff in here  _END_',
#  '_START_ great tasting coffee  _END_',
#  '_START_ bully sticks  _END_',
#  '_START_ great stuff  _END_',
#  '_START_ my cats go wild for this stuff  _END_',
#  '_START_ these are absolutely revolting  _END_',
#  '_START_ another canidae product my dogs love  _END_',
#  '_START_ my go to sweetner  _END_',
#  '_START_ the best for risotto  _END_',
#  '_START_ great taste  _END_',
#  '_START_ cheapest place is amazon  _END_',
#  '_START_ good deal  _END_',
#  '_START_ sooo good  _END_',
#  '_START_ nice caramel flavor  _END_',
#  '_START_ bbq is terrific  _END_',
#  '_START_ my kids love them  _END_',
#  '_START_ great taste pain to strain  _END_',
#  '_START_ we love salsa  _END_',
#  '_START_ decaf never tasted so good stars  _END_',
#  '_START_ chocolot  _END_',
#  '_START_ great taste  _END_',
#  '_START_ my cats love this real food cat food  _END_',
#  '_START_ the best part of early summer  _END_',
#  '_START_ really good chips  _END_',
#  '_START_ very tasty  _END_',
#  '_START_ my daughter first word was cracker  _END_',
#  '_START_ careful of the price  _END_',
#  '_START_ agree with lucas  _END_',
#  '_START_ has very good flavor  _END_',
#  '_START_ healthy snack  _END_',
#  '_START_ aluminum free  _END_',
#  '_START_ tasty on its own but bit too much sugar  _END_',
#  '_START_ big disappointment  _END_',
#  '_START_ sooooooooooo easy  _END_',
#  '_START_ delicious strong japanese black coffee candy  _END_',
#  '_START_ delicious  _END_',
#  '_START_ like to gamble buying the st patty dried fruit basket is crap shoot  _END_',
#  '_START_ french roast coffee  _END_',
#  '_START_ good ingredients weak taste  _END_',
#  '_START_ could drink this stuff  _END_',
#  '_START_ happy customer  _END_',
#  '_START_ delicious little gummy bears  _END_',
#  '_START_ tastes like european hot chocolate  _END_',
#  '_START_ disgusting  _END_',
#  '_START_ great tea  _END_',
#  '_START_ great  _END_',
#  '_START_ delivers what was promises  _END_',
#  '_START_ easy and tasty for better health  _END_',
#  '_START_ great choice for those who are gluten free  _END_',
#  '_START_ great for pancakes  _END_',
#  '_START_ organic is great but  _END_',
#  '_START_ very good cup of coffee  _END_',
#  '_START_ yum  _END_',
#  '_START_ great pasta  _END_',
#  '_START_ fresh coffee  _END_',
#  '_START_ good but container could be better  _END_',
#  '_START_ great price on great product  _END_',
#  '_START_ odd tasting but natural  _END_',
#  '_START_ inexpensive meal  _END_',
#  '_START_ great easy product  _END_',
#  '_START_ great  _END_',
#  '_START_ more than just taste of thai  _END_',
#  '_START_ good and tasty  _END_',
#  '_START_ great for cakes  _END_',
#  '_START_ it was just what wanted  _END_',
#  '_START_ my gluten free bisquick review  _END_',
#  '_START_ chrysanthemum tea taste great with lemons and apriva  _END_',
#  '_START_ libby organic corn  _END_',
#  '_START_ fully enjoyed  _END_',
#  '_START_ best salt vinegar  _END_',
#  '_START_ actually pretty good  _END_',
#  '_START_ no more guilt snacking the grand babies  _END_',
#  '_START_ it is not decaf people  _END_',
#  '_START_ liver biscotti rules in our house  _END_',
#  '_START_ spicy mustard  _END_',
#  '_START_ they have been around forever but you did not know it  _END_',
#  '_START_ disposable cups  _END_',
#  '_START_ recipe hot choc for grown ups  _END_',
#  '_START_ nothing special  _END_',
#  '_START_ my olvatine  _END_',
#  '_START_ stonewall kitchen pancake and waffle mix is grrrrrreat  _END_',
#  '_START_ carbonated juice beats sodas  _END_',
#  '_START_ not corn muffin for cornhusker  _END_',
#  '_START_ stars and thumbs up  _END_',
#  '_START_ no brainer  _END_',
#  '_START_ they re so good they evaporate  _END_',
#  '_START_ my cats love these  _END_',
#  '_START_ very flavorfull  _END_',
#  '_START_ oatcakes  _END_',
#  '_START_ luzianne is awesome  _END_',
#  '_START_ not for traditional caramel lovers  _END_',
#  '_START_ awesome tofu great price  _END_',
#  '_START_ tasty  _END_',
#  '_START_ mona lisa  _END_',
#  '_START_ awesome similac organic formula  _END_',
#  '_START_ the best bad breath and no fowl after taste  _END_',
#  '_START_ tasty treat  _END_',
#  '_START_ great dog food  _END_',
#  '_START_ pretty good stuff with the right sweetener  _END_',
#  '_START_ good just not what was looking for  _END_',
#  '_START_ shipped great  _END_',
#  '_START_ gevalia melange maison corse  _END_',
#  '_START_ highly addicitive chips  _END_',
#  '_START_ misleading  _END_',
#  '_START_ rich and full  _END_',
#  '_START_ my cats love it  _END_',
#  '_START_ what deal  _END_',
#  '_START_ love mrs may products  _END_',
#  '_START_ great tasting sea salt with iodine  _END_',
#  '_START_ perfect for sweet tooth just coming off gluten  _END_',
#  '_START_ probably would be better to make something like this from scratch  _END_',
#  '_START_ valentine gift winner  _END_',
#  '_START_ the easiest good coffee ever  _END_',
#  '_START_ ginger day  _END_',
#  '_START_ jamaica me happy  _END_',
#  '_START_ yummy  _END_',
#  '_START_ this baking soda is the bomb  _END_',
#  '_START_ grandson loves them  _END_',
#  '_START_ ghirardelli has done it again  _END_',
#  '_START_ pg tips in the bags  _END_',
#  '_START_ great alternative to flax or fish oil  _END_',
#  '_START_ son loves it  _END_',
#  '_START_ best tea ever  _END_',
#  '_START_ amazing worth every penny  _END_',
#  '_START_ poorly sealed  _END_',
#  '_START_ ehkkkkkkkkkkkkkkk  _END_',
#  '_START_ fragrant delicious and cheap  _END_',
#  '_START_ how miss the taste of sugar  _END_',
#  '_START_ tasty  _END_',
#  '_START_ yummy  _END_',
#  '_START_ azing mberry definitely works and is ton of fun  _END_',
#  '_START_ cup fan  _END_',
#  '_START_ changed formula makes cats sick  _END_',
#  '_START_ it still the same  _END_',
#  '_START_ not too shabby  _END_',
#  '_START_ great treats  _END_',
#  '_START_ sweeter than sugar  _END_',
#  '_START_ very disapointed  _END_',
#  '_START_ delicious  _END_',
#  '_START_ my cat loves this food  _END_',
#  '_START_ it would be if it were not for the rocks  _END_',
#  '_START_ best for on the road snacks and health  _END_',
#  '_START_ bisquick gluten free  _END_',
#  '_START_ good cat food  _END_',
#  '_START_ gluten free with good taste  _END_',
#  '_START_ am somewhat distressed  _END_',
#  '_START_ surprising find  _END_',
#  '_START_ overall  _END_',
#  '_START_ great chips great flavor  _END_',
#  '_START_ one of my favorites  _END_',
#  '_START_ new formulation for is not good at all  _END_',
#  '_START_ good reliable results expensive  _END_',
#  '_START_ great iron content and decent taste  _END_',
#  '_START_ fluffy soft delicious and sugary sweet  _END_',
#  '_START_ great quality food my cats hate it though  _END_',
#  '_START_ tasty enjoyable pure juice carbonated drink  _END_',
#  '_START_ my son loves these cookie bars  _END_',
#  '_START_ good product  _END_',
#  '_START_ fruitcake in june  _END_',
#  '_START_ the best cup  _END_',
#  '_START_ almost perfect  _END_',
#  '_START_ good surprise  _END_',
#  '_START_ great natural orange taste tough price  _END_',
#  '_START_ nice to have in the pantry  _END_',
#  '_START_ delicious product  _END_',
#  '_START_ best tasting coconut water have found  _END_',
#  '_START_ great product  _END_',
#  '_START_ good coffee  _END_',
#  '_START_ dessert to them but is it nutritional enough  _END_',
#  '_START_ not full leaf pound not pounds  _END_',
#  '_START_ great  _END_',
#  '_START_ great product  _END_',
#  '_START_ worked as expected  _END_',
#  '_START_ this is great stuff  _END_',
#  '_START_ only use earth best products  _END_',
#  '_START_ agar good price worked well as food stablizer  _END_',
#  '_START_ gummy bears  _END_',
#  '_START_ like glass of great wine  _END_',
#  '_START_ love it delicious  _END_',
#  '_START_ great taste crunchy  _END_',
#  '_START_ the absolute best cracker for those watching their carb intake  _END_',
#  '_START_ great variety  _END_',
#  '_START_ drink without category  _END_',
#  '_START_ possibly the best energy drink out there  _END_',
#  '_START_ not banana runts  _END_',
#  '_START_ mmmmmmmm  _END_',
#  '_START_ awesome taste but  _END_',
#  '_START_ great chip substitute  _END_',
#  '_START_ love it  _END_',
#  '_START_ best cereal ever  _END_',
#  '_START_ absolutely delicous product  _END_',
#  '_START_ slow start warm finish  _END_',
#  '_START_ best hot sauce around  _END_',
#  '_START_ very good nutritionally but expensive and clumpy  _END_',
#  '_START_ yummy very tasty and easy to work with  _END_',
#  '_START_ oh my goodness reminds me of girl scout cookies from  _END_',
#  '_START_ received wrong product  _END_',
#  '_START_ best beef jerky so far  _END_',
#  '_START_ poor product  _END_',
#  '_START_ since got the marinated morsals that is all my cat will eat  _END_',
#  '_START_ sweet tea  _END_',
#  '_START_ meh  _END_',
#  '_START_ kavli crackers are an important part of my diet  _END_',
#  '_START_ terrible  _END_',
#  '_START_ questionable healthy drink  _END_',
#  '_START_ good and gluten free  _END_',
#  '_START_ bisquick gluten free  _END_',
#  '_START_ best rawhides available anywhere  _END_',
#  '_START_ my fussy min dachshund loves the taste  _END_',
#  '_START_ great stuff  _END_',
#  '_START_ one of their best flavors  _END_',
#  '_START_ not if you have had the regular version otherwise okay  _END_',
#  '_START_ arrived fresh and in good shape  _END_',
#  '_START_ really good gluten free pancakes  _END_',
#  '_START_ tastes great  _END_',
#  '_START_ this is very fine tasting full lea great value  _END_',
#  '_START_ great natural energy  _END_',
#  '_START_ yummers  _END_',
#  '_START_ love wolfgang puck soups  _END_',
#  '_START_ huge success  _END_',
#  '_START_ the best  _END_',
#  '_START_ rip off price  _END_',
#  '_START_ very good  _END_',
#  '_START_ my daughter loves this milk  _END_',
#  '_START_ good tea use french press to filter  _END_',
#  '_START_ my cats love them  _END_',
#  '_START_ bang  _END_',
#  '_START_ good for you but not best flavor  _END_',
#  '_START_ the ultimate sweet and sour sauce  _END_',
#  '_START_ wonderful coffee with hint of dark chocolate  _END_',
#  '_START_ the best  _END_',
#  '_START_ perfect for little toddler hands  _END_',
#  '_START_ this coffee smells like farts  _END_',
#  '_START_ save money  _END_',
#  '_START_ hard to find  _END_',
#  '_START_ great coffee  _END_',
#  '_START_ as described but difficult to use  _END_',
#  '_START_ are these all the cups that come out of other packages  _END_',
#  '_START_ they re good seeds  _END_',
#  '_START_ favorite quick meal solution  _END_',
#  '_START_ awesome product  _END_',
#  '_START_ very good tea  _END_',
#  '_START_ yummy  _END_',
#  '_START_ premium dog food  _END_',
#  '_START_ god love these cookies  _END_',
#  '_START_ gritty for no reason  _END_',
#  '_START_ great snacking alternative  _END_',
#  '_START_ best pancakes ever  _END_',
#  '_START_ quite good cup of instant coffee  _END_',
#  '_START_ little ones like them and no soy  _END_',
#  '_START_ convenient and tasty too  _END_',
#  '_START_ awesome cat food  _END_',
#  '_START_ quick easy taste great  _END_',
#  '_START_ nutty spice  _END_',
#  '_START_ great healthy alternative to soda pop  _END_',
#  '_START_ made for one interesting night  _END_',
#  '_START_ great orange bevvie  _END_',
#  '_START_ holistic select cat food  _END_',
#  '_START_ yummy  _END_',
#  '_START_ yum  _END_',
#  '_START_ cheap  _END_',
#  '_START_ oyster sauce  _END_',
#  '_START_ decent earl grey  _END_',
#  '_START_ from person with very limited diet  _END_',
#  '_START_ thought it was exceptional  _END_',
#  '_START_ great for hot mocha latte  _END_',
#  '_START_ delicious  _END_',
#  '_START_ little too much bitterness acid  _END_',
#  '_START_ dirty martini olive juice  _END_',
#  '_START_ do not even like kettle chips and love these  _END_',
#  '_START_ it the best for coffee  _END_',
#  '_START_ great dog food for dogs with digestive problems  _END_',
#  '_START_ great pick me up on the go hot or cold  _END_',
#  '_START_ candy for dogs  _END_',
#  '_START_ very nice  _END_',
#  '_START_ great chocolate  _END_',
#  '_START_ love the smaller bags  _END_',
#  '_START_ would buy again  _END_',
#  '_START_ disposakups  _END_',
#  '_START_ good mix in with other looseleaf teas  _END_',
#  '_START_ rocket in bottle  _END_',
#  '_START_ small kernals  _END_',
#  '_START_ false advertising terrible dog food  _END_',
#  '_START_ actually pretty good  _END_',
#  '_START_ love it  _END_',
#  '_START_ the best  _END_',
#  '_START_ not really jerky  _END_',
#  '_START_ superlative store bought cookies very hard to find  _END_',
#  '_START_ surprisingly tasty  _END_',
#  '_START_ strange flavor  _END_',
#  '_START_ not good  _END_',
#  '_START_ blech  _END_',
#  '_START_ fabulous  _END_',
#  '_START_ magical  _END_',
#  '_START_ handy but not to tasty  _END_',
#  '_START_ not so much  _END_',
#  '_START_ neat stuff  _END_',
#  '_START_ makes excellent biryani  _END_',
#  '_START_ the best soda ever  _END_',
#  '_START_ makes good cup of coffee  _END_',
#  '_START_ best tasting so far  _END_',
#  '_START_ crunchy healthy satisfying goodness in every bite  _END_',
#  '_START_ bad flavor combination  _END_',
#  '_START_ oh so bitter tasting  _END_',
#  '_START_ riceworks salsa fresca chips  _END_',
#  '_START_ best hot sauce and taco sauce available in america  _END_',
#  '_START_ very good hot chocolate  _END_',
#  '_START_ very tasty natural drink  _END_',
#  '_START_ omg do not buy  _END_',
#  '_START_ wonderful tea  _END_',
#  '_START_ disappointment  _END_',
#  '_START_ snappy white popcorn  _END_',
#  '_START_ smells great  _END_',
#  '_START_ be very berry wary  _END_',
#  '_START_ really good gravy  _END_',
#  '_START_ yummy  _END_',
#  '_START_ unfilled cans  _END_',
#  '_START_ people are so picky  _END_',
#  '_START_ organic golden  _END_',
#  '_START_ popchips  _END_',
#  '_START_ not bad bit light  _END_',
#  '_START_ delicious  _END_',
#  '_START_ one of my top favorites  _END_',
#  '_START_ it works and was fun  _END_',
#  '_START_ my happy dog  _END_',
#  '_START_ works but hard to open buy larger version instead of pod  _END_',
#  '_START_ vitakraft carob drops  _END_',
#  '_START_ pretty cool but not life changing  _END_',
#  '_START_ crunchy tart  _END_',
#  '_START_ okay  _END_',
#  '_START_ excellent for  _END_',
#  '_START_ sorry  _END_',
#  '_START_ kill cliff sports recovery drink  _END_',
#  '_START_ good popcorn  _END_',
#  '_START_ gross cookies  _END_',
#  '_START_ healthy selection  _END_',
#  '_START_ best golden berries have ever had  _END_',
#  '_START_ fizzlicious and tangy  _END_',
#  '_START_ great  _END_',
#  '_START_ gooood coffee  _END_',
#  '_START_ nice  _END_',
#  '_START_ best pizza since have been gluten free  _END_',
#  '_START_ yummy  _END_',
#  '_START_ eat with caution  _END_',
#  '_START_ these are weird  _END_',
#  '_START_ smells like roses but no safety or freshness seal  _END_',
#  '_START_ great product to help you sleep  _END_',
#  '_START_ delicious low cal treat  _END_',
#  '_START_ great chips  _END_',
#  '_START_ words cannot describe how wonderful extra dessert delights gum is  _END_',
#  '_START_ awesome product  _END_',
#  '_START_ will know more when actually use it first  _END_',
#  '_START_ overpriced  _END_',
#  '_START_ yum  _END_',
#  '_START_ loved  _END_',
#  '_START_ best cup hot cocoa  _END_',
#  '_START_ cafe excellence crazy caramet whole beans pound  _END_',
#  '_START_ aluminum free baking soda  _END_',
#  '_START_ easy for the babysitter  _END_',
#  '_START_ soothing calming allows you to relax and rest  _END_',
#  '_START_ southeastern mills peppered gravy mix oz bag  _END_',
#  '_START_ great energy sustainer tastes delicious no caffeine  _END_',
#  '_START_ low calorie dental sticks  _END_',
#  '_START_ dog best friend  _END_',
#  '_START_ great tasting coffee  _END_',
#  '_START_ plum is the best  _END_',
#  '_START_ these are the best widely available bbq chips  _END_',
#  '_START_ easy to order great in recipes  _END_',
#  '_START_ item covered in walnuts needs to have allergens listed  _END_',
#  '_START_ awful  _END_',
#  '_START_ best instant coffee ever tasted  _END_',
#  '_START_ these cups melted during the coffee brewing process  _END_',
#  '_START_ great snack  _END_',
#  '_START_ these beans were wonderful  _END_',
#  '_START_ water low sodium sardines that actually taste good  _END_',
#  '_START_ awesome  _END_',
#  '_START_ despite the reviews here think most people would agree with me  _END_',
#  '_START_ fantastic but over priced  _END_',
#  '_START_ had much higher hopes  _END_',
#  '_START_ excellent choice  _END_',
#  '_START_ better tasting than most healthier or high fiber cereals  _END_',
#  '_START_ versatile  _END_',
#  '_START_ yummy  _END_',
#  '_START_ jamaica me crazy is our favorite cup so far  _END_',
#  '_START_ warning warning alcohol sugars  _END_',
#  '_START_ lives chicken tuna dinner  _END_',
#  '_START_ decent deal  _END_',
#  '_START_ super chia seeds  _END_',
#  '_START_ yummm  _END_',
#  '_START_ little venus fly trap  _END_',
#  '_START_ snickerdoodles  _END_',
#  '_START_ great product  _END_',
#  '_START_ very disappointed  _END_',
#  '_START_ hawaiian hazelnut always out of stock  _END_',
#  '_START_ delicious  _END_',
#  '_START_ wonderful this is perfect and saves me fortune  _END_',
#  '_START_ these cookies need work you can make your own at home  _END_',
#  '_START_ bob red mill pumpkin seeds raw  _END_',
#  '_START_ my tea  _END_',
#  '_START_ delicious nutritious and great buy  _END_',
#  '_START_ wolfgang puck sumatra  _END_',
#  '_START_ mccanns steel cut oatmeal  _END_',
#  '_START_ lives up to its appealing name  _END_',
#  '_START_ absolutely delicious  _END_',
#  '_START_ snowflake tea decadence in cup  _END_',
#  '_START_ one of the best oils on the market  _END_',
#  '_START_ best non whey non soy alternative  _END_',
#  '_START_ great taste not overly sweet  _END_',
#  '_START_ very good  _END_',
#  '_START_ grandpa po are majorly addictive  _END_',
#  '_START_ one of my favorites  _END_',
#  '_START_ was addicted to this stuff for while but wore myself out  _END_',
#  '_START_ short and sweet  _END_',
#  '_START_ yum yum mishmash  _END_',
#  '_START_ difficult to find tastes great  _END_',
#  '_START_ bit too sweet for my taste  _END_',
#  '_START_ simply nasty  _END_',
#  '_START_ they re not bad  _END_',
#  '_START_ great  _END_',
#  '_START_ floral tasting tea  _END_',
#  '_START_ bit of disappointment on two fronts  _END_',
#  '_START_ good and just enough to satisfy you  _END_',
#  ...]

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
x_tr.shape
# Out:
# (8554, 80)

# %%
max_len_text
# Out:
# 80

# %%
max_len_summary
# Out:
# 10

# %%
y_voc_size
# Out:
# 4250

# %%
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary(200)
# Out:
# Model: "functional_3"
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Layer (type)                                                      Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
# input_3 (InputLayer)                                              [(None, 80)]                                0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# embedding_2 (Embedding)                                           (None, 80, 500)                             8455000                 input_3[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# lstm_4 (LSTM)                                                     [(None, 80, 500), (None, 500), (None, 500)] 2002000                 embedding_2[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# input_4 (InputLayer)                                              [(None, None)]                              0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# lstm_5 (LSTM)                                                     [(None, 80, 500), (None, 500), (None, 500)] 2002000                 lstm_4[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# embedding_3 (Embedding)                                           (None, None, 500)                           2125000                 input_4[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# lstm_6 (LSTM)                                                     [(None, 80, 500), (None, 500), (None, 500)] 2002000                 lstm_5[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# lstm_7 (LSTM)                                                     [(None, None, 500), (None, 500), (None, 500 2002000                 embedding_3[0][0]
#                                                                                                                                       lstm_6[0][1]
#                                                                                                                                       lstm_6[0][2]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# attention_layer (AttentionLayer)                                  ((None, None, 500), (None, None, 80))       500500                  lstm_6[0][0]
#                                                                                                                                       lstm_7[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# concat_layer (Concatenate)                                        (None, None, 1000)                          0                       lstm_7[0][0]
#                                                                                                                                       attention_layer[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# time_distributed_1 (TimeDistributed)                              (None, None, 4250)                          4254250                 concat_layer[0][0]
# ========================================================================================================================================================================================================
# Total params: 23,342,750
# Trainable params: 23,342,750
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=256, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 34/34 [==============================] - 10s 282ms/step - loss: 2.6596 - val_loss: 2.5167
# Epoch 2/50
# 34/34 [==============================] - 10s 281ms/step - loss: 2.5840 - val_loss: 2.5167
# Epoch 3/50
# 34/34 [==============================] - 10s 281ms/step - loss: 2.5041 - val_loss: 2.4687
# Epoch 4/50
# 34/34 [==============================] - 10s 281ms/step - loss: 2.4175 - val_loss: 2.4666
# Epoch 5/50
# 34/34 [==============================] - 10s 283ms/step - loss: 2.3282 - val_loss: 2.4473
# Epoch 6/50
# 34/34 [==============================] - 10s 281ms/step - loss: 2.2353 - val_loss: 2.4112
# Epoch 7/50
# 34/34 [==============================] - 10s 280ms/step - loss: 2.1401 - val_loss: 2.4030
# Epoch 8/50
# 34/34 [==============================] - 9s 279ms/step - loss: 2.0467 - val_loss: 2.4089
# Epoch 00008: early stopping

# %%
model.save(proj_dir+"trained.h5")

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['_START_']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='_END_'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == '_END_'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['_START_']) and i!=target_word_index['_END_']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: year old eats chocolate munch cookie loves bought gluten free sweetener free calls chocolate treat gives indication good thinks would definitely recommend flavor everyone found subscribe save discount get boxes cheaper amazon stores like sunflower sprouts whole foods
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-0e69bf8de83c> in <module>()
#       1 for i in range(0,100):
#       2     print("Review:",seq2text(x_tr[i]))
# ----> 3     print("Original summary:",seq2summary(y_tr[i]))
#       4     print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
#       5     print("\n")
#
# <ipython-input-145-8e3ccfc6f8da> in seq2summary(input_seq)
#       2     newString=''
#       3     for i in input_seq:
# ----> 4         if((i!=0 and i!=target_word_index['_START_']) and i!=target_word_index['_END_']):
#       5             newString=newString+reverse_target_word_index[i]+' '
#       6     return newString
#
# KeyError: '_START_'
